# %% [markdown]
# # Î†ÏƒÎºÎ·ÏƒÎ· 5 : Î•Ï€Î¹Î²Î»ÎµÏ€ÏŒÎ¼ÎµÎ½Î· Î¤Î±Î¾Î¹Î½ÏŒÎ¼Î·ÏƒÎ· Î¼Îµ ÎÎµÏ…ÏÏ‰Î½Î¹ÎºÎ¬ Î”Î¯ÎºÏ„Ï…Î±
#
# ## Î•Î¹ÏƒÎ±Î³Ï‰Î³Î® ÏƒÏ„Î¿ Keras

# %% [markdown]
# Î£ÎºÎ¿Ï€ÏŒÏ‚ Î±Ï…Ï„Î®Ï‚ Ï„Î·Ï‚ Î¬ÏƒÎºÎ·ÏƒÎ·Ï‚ ÎµÎ¯Î½Î±Î¹ Î· ÎµÏ€Î¹Î²Î»ÎµÏ€ÏŒÎ¼ÎµÎ½Î· Ï„Î±Î¾Î¹Î½ÏŒÎ¼Î·ÏƒÎ· ÏƒÏ„Î¿ [Iris Dataset](http://archive.ics.uci.edu/ml/datasets/Iris). ÎœÎ­ÏƒÏ‰ Î±Ï…Ï„Î®Ï‚ Î¸Î± Î­ÏÎ¸ÎµÏ„Îµ ÏƒÎµ Î¼Î¯Î± Ï€ÏÏŽÏ„Î· ÎµÏ€Î±Ï†Î® Î¼Îµ Ï„Î¿ Keras ÎºÎ±Î¹ Î¸Î± ÎµÎ¾Î¿Î¹ÎºÎµÎ¹Ï‰Î¸ÎµÎ¯Ï„Îµ Î¼Îµ Î²Î±ÏƒÎ¹ÎºÎ­Ï‚ Î±ÏÏ‡Î­Ï‚ Ï„Î·Ï‚ ÎœÎ·Ï‡Î±Î½Î¹ÎºÎ®Ï‚ ÎœÎ¬Î¸Î·ÏƒÎ·Ï‚.

# %% [markdown]
# ### Î’Î®Î¼Î± 1 : Î•Î¹ÏƒÎ±Î³Ï‰Î³Î® Î´ÎµÎ´Î¿Î¼Î­Î½Ï‰Î½

# %%
import urllib.request
iris_data_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
urllib.request.urlretrieve(iris_data_url, 'iris.data')

data = pd.read_csv('iris.data', header=None)
data.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'label']
print(data)

# %% [markdown]
# Î•Î½Î±Î»Î»Î±ÎºÏ„Î¹ÎºÎ¬, Î¼Ï€Î¿ÏÎµÎ¯Ï„Îµ Î½Î± ÎºÎ±Ï„ÎµÎ²Î¬ÏƒÎµÏ„Îµ Ï„Î¿Ï€Î¹ÎºÎ¬ Ï„Î¿ ÏƒÎµÏ„ Î´ÎµÎ´Î¿Î¼Î­Î½Ï‰Î½ Î±Ï€ÏŒ Ï„Î¿Î½ Ï€Î±ÏÎ±Ï€Î¬Î½Ï‰ ÏƒÏÎ½Î´ÎµÏƒÎ¼Î¿.

# %% [markdown]
# ### Î’Î®Î¼Î± 2 : ÎŸÏ€Ï„Î¹ÎºÎ¿Ï€Î¿Î¯Î·ÏƒÎ· Î´ÎµÎ´Î¿Î¼Î­Î½Ï‰Î½
# Î”Î·Î¼Î¹Î¿Ï…ÏÎ³ÎµÎ¯ÏƒÏ„Îµ scatterplots (Î¼Îµ Ï„Î· Î²Î¿Î®Î¸ÎµÎ¹Î± Ï„Î·Ï‚ Î²Î¹Î²Î»Î¹Î¿Î¸Î®ÎºÎ·Ï‚ matplotlib) Ï„Ï‰Î½ Î´ÎµÎ´Î¿Î¼Î­Î½Ï‰Î½.

# %%
print('Replace me with code!')

# %% [markdown]
# ### Î’Î®Î¼Î± 3 : Î ÏÎ¿ÎµÏ€ÎµÎ¾ÎµÏÎ³Î±ÏƒÎ¯Î± Î´ÎµÎ´Î¿Î¼Î­Î½Ï‰Î½

# %% [markdown]
# #### 3.1.  Î§Ï‰ÏÎ¯ÏƒÏ„Îµ Ï„Î± Î´ÎµÎ´Î¿Î¼Î­Î½Î± ÏƒÎµ ÏƒÏÎ½Î¿Î»Î± ÎµÎºÏ€Î±Î¯Î´ÎµÏ…ÏƒÎ·Ï‚ ÎºÎ±Î¹ Î±Î¾Î¹Î¿Î»ÏŒÎ³Î·ÏƒÎ·Ï‚

# %%
random_state = 2019
print('Replace me with code!')

# %% [markdown]
# #### 3.2.  ÎœÎµÏ„Î±Ï„ÏÎ­ÏˆÏ„Îµ Ï„Î± labels ÏƒÎµ Î´Î¹Î±Î½ÏÏƒÎ¼Î±Ï„Î± ÎºÎ±Ï„Î·Î³Î¿ÏÎ¹ÏŽÎ½ (categorical) Î¼Îµ Ï„Î· Ï‡ÏÎ®ÏƒÎ· one-hot encoding

# %%
print('Replace me with code!')

# %% [markdown]
# #### 3.3.  ÎšÎ±Î½Î¿Î½Î¹ÎºÎ¿Ï€Î¿Î¹Î®ÏƒÏ„Îµ Ï„Î± Î´ÎµÎ´Î¿Î¼Î­Î½Î± ÏƒÏ„Î¿ Î´Î¹Î¬ÏƒÏ„Î·Î¼Î± [-1,1]

# %%
print('Replace me with code!')

# %% [markdown]
# ### Î’Î®Î¼Î± 4 : Î”Î·Î¼Î¹Î¿Ï…ÏÎ³ÎµÎ¯ÏƒÏ„Îµ Ï„Î¿ Î½ÎµÏ…ÏÏ‰Î½Î¹ÎºÏŒ Î´Î¯ÎºÏ„Ï…Î¿ Ï„Î·Ï‚ ÎµÎºÏ†ÏŽÎ½Î·ÏƒÎ·Ï‚

# %%
print('Replace me with code!')

# %% [markdown]
# ### Î’Î®Î¼Î± 5 : Î•ÎºÏ€Î±Î¹Î´ÎµÏÏƒÏ„Îµ Ï„Î¿ Î¼Î¿Î½Ï„Î­Î»Î¿

# %%
print('Replace me with code!')

# %% [markdown]
# #### 5.1.  Î•Î¼Ï†Î±Î½Î¯ÏƒÏ„Îµ Ï„Î± Î´Î¹Î±Î³ÏÎ¬Î¼Î¼Î±Ï„Î±
# *   **Loss vs Epoch**
# *   **Accuracy vs Epoch**

# %%
print('Replace me with code!')

# %% [markdown]
# ### Î’Î®Î¼Î± 6 : Î‘Î¾Î¹Î¿Î»Î¿Î³Î®ÏƒÏ„Îµ Ï„Î¿ Î¼Î¿Î½Ï„Î­Î»Î¿

# %%
print('Replace me with code!')

# %% [markdown]
# #### Extra : Î”Î¿ÎºÎ¹Î¼Î¬ÏƒÏ„Îµ Î½Î± Ï‡ÏÎ·ÏƒÎ¹Î¼Î¿Ï€Î¿Î¹Î®ÏƒÎµÏ„Îµ ÎºÎ±Î¹ Î¬Î»Î»Î¿Ï…Ï‚ "ÎºÎ»Î±ÏƒÏƒÎ¹ÎºÎ¿ÏÏ‚" Ï„Î±Î¾Î¹Î½Î¿Î¼Î·Ï„Î­Ï‚

# %%
print('Replace me with code!')
